# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from statsmodels.graphics.tsaplots import plot_acf
# from statsmodels.tsa.stattools import adfuller


# Step 2 - reading the dataset using read_csv
df = pd.read_csv("stock_data.csv", 
				parse_dates=True, 
				index_col="Date")

# displaying the first five rows of dataset
df.head()
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#             Turnover (Lacs)
# Date
# 2018-09-28          7162.35
# 2018-09-27         11859.95
# 2018-09-26          5248.60
# 2018-09-25          5503.90
# 2018-09-24          7999.55

# %%
# Step 3 - Assuming df is your DataFrame
sns.set(style="whitegrid") # Setting the style to whitegrid for a clean background

plt.figure(figsize=(12, 6)) # Setting the figure size
sns.lineplot(data=df, x='Date', y='High', label='High Price', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Share Highest Price Over Time')

plt.show()


# Step 4 - Assuming df is your DataFrame with a datetime index
df_resampled = df.resample('M').mean() # Resampling to monthly frequency, using mean as an aggregation function

sns.set(style="whitegrid") # Setting the style to whitegrid for a clean background

# Plotting the 'high' column with seaborn, setting x as the resampled 'Date'
plt.figure(figsize=(12, 6)) # Setting the figure size
sns.lineplot(data=df_resampled, x=df_resampled.index, y='High', label='Month Wise Average High Price', color='blue')

# Adding labels and title
plt.xlabel('Date (Monthly)')
plt.ylabel('High')
plt.title('Monthly Resampling Highest Price Over Time')

plt.show()


# Step 5 - Differencing
df['high_diff'] = df['High'].diff()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label='Original High', color='blue')
plt.plot(df['high_diff'], label='Differenced High', linestyle='--', color='green')
plt.legend()
plt.title('Original vs Differenced High')
plt.show()
# Out:
# C:\Users\Deepak\AppData\Local\Temp\ipykernel_22984\259160464.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_resampled = df.resample('M').mean() # Resampling to monthly frequency, using mean as an aggregation function

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.14.2-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.12.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.2.1)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\deepak\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Using cached statsmodels-0.14.2-cp311-cp311-win_amd64.whl (9.9 MB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2
# Note: you may need to restart the kernel to use updated packages.
